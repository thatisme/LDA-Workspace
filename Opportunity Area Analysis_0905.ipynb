# %%
import pandas as pd

# %% [markdown]
# ### 1. 데이터 로딩

# %%
df = pd.read_csv("./4. LDA_result/df_action_cluster_save.csv")
df.drop(labels='Unnamed: 0.1', axis = 1, inplace=True) # 필요 없는 열 데이터 제거
df.drop(labels='Unnamed: 0', axis = 1, inplace=True) # 필요 없는 열 데이터 제거
df.drop(labels='cluster', axis = 1, inplace=True) # 필요 없는 열 데이터 제거
df
# Out:
#                                                    text  star  \
# 0     ['waste', 'money', 'ac', 'work', 'till', 'one'...     1
# 1     ['purchase', 'lg', 'april', 'the', 'horrible',...     1
# 2     ['want', 'buy', 'white', 'showpiece', 'bedroom...     1
# 3     ['totally', 'waste', 'money', 'company', 'refu...     1
# 4     ['model', 'way', 'swing', 'actual', 'ton', 'co...     1
# ...                                                 ...   ...
# 6830  ['pricing', 'high', 'kg', 'wash', 'machine', '...     2
# 6831  ['recieved', 'part', 'item', 'show', 'picture'...     1
# 6832  ['wash', 'machine', 'two', 'part', 'deliver', ...     1
# 6833  ['advertise', 'get', 'bottom', 'part', 'wash',...     1
# 6834  ['almost', 'month', 'expensive', 'box', 'lie',...     1
#
#                                                original  action_cluster
# 0     Waste of money . AC not working till one month...               1
# 1     I purchased this LG A. C. on 17 April 23..The ...               5
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6835 entries, 0 to 6834
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   text            6835 non-null   object
#  1   star            6835 non-null   int64
#  2   original        6778 non-null   object
#  3   action_cluster  6835 non-null   int64
# dtypes: int64(2), object(2)
# memory usage: 213.7+ KB
