# %%
import pandas as pd

# CSV 파일 불러오기
df1 = pd.read_csv('user_list_tv1.csv', encoding='utf-8-sig')
df2 = pd.read_csv('review_list_tv1.csv', encoding='utf-8-sig')

# %%
len(df1)
# Out:
# 35

# %%
df2
# Out:
#                                                  User
# 0                gags\nIndia\nGenderMale\nAge25 to 34
# 1              Sushil\nDelhi\nGenderMale\nAge35 to 44
# 2             DSC\nHyderabad\nGenderMale\nAge35 to 44
# 3                                           Nikhilesh
# 4          Abhimanyu\nKanpur\nGenderMale\nAge25 to 34
# 5                   Prasanth\nGenderMale\nAge45 to 54
# 6           Satish\nkolhapur\nGenderMale\nAge45 to 54
# 7                        Gee\nGenderMale\nAge35 to 44
# 8                                           Madhu0117
# 9                  Anonymous\nGenderMale\nAge35 to 44
# 10                                             Manish
# 11          G max\nMangalore\nGenderMale\nAge35 to 44
# 12       Jay\nPandharapur MH\nGenderMale\nAge35 to 44
# 13     EmeraldWall\nHaldwani\nGenderMale\nAge25 to 34
# 14         Surag\nTrivandrum\nGenderMale\nAge45 to 54
# 15             Mitesh\nSurat\nGenderMale\nAge18 to 24
# ...

# %%
df2
# Out:
#                                                Review
# 0   1 out of 5 stars.\nSTAY AWAY FROM THESE TVS\n2...
# 1   1 out of 5 stars.\nPROBLEM IN PANEL WITHIN A W...
# 2   3 out of 5 stars.\nGOOD PICTURE QUALITY\n10 MO...
# 3   4 out of 5 stars.\nGREAT FEATURES, GOOD PICTUR...
# 4   4 out of 5 stars.\nILKE THIS LG TV\n8 DAYS AGO...
# 5   4 out of 5 stars.\n18 DAYS AGO\nProduct good b...
# 6   4 out of 5 stars.\n3 MONTHS AGO\nThe LED TV is...
# 7   4 out of 5 stars.\nGREAT VIEWING EXPERIENCE\n9...
# 8   4 out of 5 stars.\nGREAT PRODUCT IN THIS PRICE...
# 9   4 out of 5 stars.\nITS A FUN TV.\nA YEAR AGO\n...
# 10  5 out of 5 stars.\nGOOD VALUE FOR MONEY\n9 DAY...
# 11  5 out of 5 stars.\nGREAT PICTURE QUALITY AND E...
# 12  5 out of 5 stars.\nGREAT PRICE\n16 DAYS AGO\nI...
# 13  5 out of 5 stars.\nGOOD FEATURES AT REASONABLE...
# 14  5 out of 5 stars.\n6 MONTHS AGO\nvery good pro...
# 15  5 out of 5 stars.\nBEST TV\n6 MONTHS AGO\nI bo...
# ...
